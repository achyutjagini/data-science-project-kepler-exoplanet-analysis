# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('cumulative-cleaned.csv')
# Numerical Plot
fig = df.head().plot.box(x = 'kepler_id', y = 'impact_parameter', title='Impact parameter VS Kepler ID')
fig = df.head().plot.box(x = 'kepler_id', y = 'equ_temp', title='Equilibrium temperature VS Kepler ID')
fig = df.head().plot.box(x = 'kepler_id', y = 'transit_duration', title='Transit Duration VS Kepler ID')

# Categorical Plot
fig = df.head().plot.bar(x = 'kepler_id', y = 'impact_parameter', title='Impact parameter VS Kepler ID')
fig = df.head().plot.bar(x = 'kepler_id', y = 'equ_temp', title='Equilibrium temperature VS Kepler ID')
fig = df.head().plot.bar(x = 'kepler_id', y = 'transit_duration', title='Transit Duration VS Kepler ID')

df.head()
# Out:
#    Unnamed: 0  rowid  kepler_id   koi_name plnt_disposition  \
# 0           0      1   10797460  K00752.01        CONFIRMED
# 1           1      2   10797460  K00752.02        CONFIRMED
# 2           2      3   10811496  K00753.01   FALSE POSITIVE
# 3           3      4   10848459  K00754.01   FALSE POSITIVE
# 4           4      5   10854555  K00755.01        CONFIRMED
#
#    plnt_disp_confidence  flag_nTransitLk  flag_scndEvent  flag_centroidOffset  \
# 0                 1.000                0               0                    0
# 1                 0.969                0               0                    0
# 2                 0.000                0               1                    0
# 3                 0.000                0               1                    0
# 4                 1.000                0               0                    0
#
#    flag_ephMatch  ...  planetary_radius  equ_temp  insolation_flux  \
# ...
